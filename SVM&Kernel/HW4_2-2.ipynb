# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from numpy import exp,arange
from pylab import meshgrid,cm,imshow,contour,clabel,colorbar,axis,title,show
# %matplotlib inline

# %%
x=np.linspace(-5,5,100)
y=-x+1
plt.plot(x,y)
theta = np.linspace(0, 2*np.pi, 100)
for i in tqdm(range(1000)):
    theta=2*np.pi*np.random.random()
    for r in [1/2,np.sqrt(2)/2,1,2,3,4]:
        x1 = r*np.cos(theta)
        x2 = r*np.sin(theta)
        if (x1+x2-1)>=0:
            plt.scatter(x1,x2,s=10,c='g')
plt.gca().set_aspect('equal')
n=0.5
plt.scatter(n,n,s=70,c='r')
# Out:
# ...
# 100%|██████████| 1000/1000 [00:02<00:00, 381.00it/s]

# %%
#x1=np.linspace(-5,5,100)
#x2=np.linspace(-5,5,100)
from tqdm import tqdm
for i in tqdm(range(50000)):
    x1=10*np.random.random()
    x2=10*np.random.random()
    temp1=np.random.random()
    temp2=np.random.random()
    if temp1>0.5:
        x1=-x1
    if temp2>0.5:
        x2=-x2
    g=1-x1-x2
    f=x1**2+x2**2
    if g<=0:
        plt.scatter(g,f,s=100,c='r')
    else:
        plt.scatter(g,f,s=100,c='g')
    
plt.xlim(-5,5)
plt.ylim(-1,10)
m=np.linspace(-10, 10, 100)
n=-m+0.5
plt.plot(m,n,c='k')
plt.scatter(0,0.5,s=100,c='b')
# Out:
# ...
#  33%|███▎      | 16403/50000 [01:39<05:34, 100.34it/s]
# ...
# ...
# 100%|██████████| 50000/50000 [17:42<00:00, 18.63it/s]

# %%
m=np.linspace(-10, 10, 100)
n=-m+0.5
plt.plot(m,n,c='k')
plt.scatter(0,0.5,s=100,c='b')
